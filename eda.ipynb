# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv("master.csv")
df.head(10)
# Out:
#    country   yea     sex          age  suicides_n  population  \
# 0  Albania  1987    male  15-24 years        21.0      312900
# 1  Albania  1987    male  35-54 years        16.0      308000
# 2  Albania  1987  female  15-24 years        14.0      289700
# 3  Albania  1987    male    75+ years         1.0       21800
# 4  Albania  1987    male  25-34 years         9.0      274300
# 5  Albania  1987  female    75+ years         1.0       35600
# 6  Albania  1987  female  35-54 years         6.0      278800
# 7  Albania  1987  female  25-34 years         4.0      257200
# 8  Albania  1987    male  55-74 years         1.0      137500
# 9  Albania  1987  female   5-14 years         0.0      311000
#
#    suicides/100k pop country-year  HDI for year    gdp_for_year  \
# 0               6.71  Albania1987           NaN  2,15,66,24,900
# 1               5.19  Albania1987           NaN  2,15,66,24,900
# 2               4.83  Albania1987           NaN  2,15,66,24,900
# ...

# %%
df.describe()
# Out:
#                 yea    suicides_n    population  suicides/100k pop  \
# count  31756.000000  30556.000000  3.175600e+04       31756.000000
# mean    2003.395390    237.136242  7.217454e+06          11.716668
# std        9.760604    867.956107  5.799323e+07          21.590926
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1996.000000      3.000000  1.288210e+05           0.370000
# 50%     2004.000000     25.000000  5.468325e+05           4.285000
# 75%     2011.000000    132.000000  2.908763e+06          14.560000
# max     2020.000000  22338.000000  1.411100e+09         515.092734
#
#        HDI for year  gdp_per_capita ($)
# count  12300.000000        31756.000000
# mean       0.793666        17588.954606
# std        0.097480        19464.861140
# min        0.377790          251.000000
# 25%        0.727000         3765.000000
# 50%        0.800457        10062.000000
# 75%        0.874000        25622.000000
# ...

# %%
df.isnull().sum()
# Out:
# country                   0
# yea                       0
# sex                       0
# age                       0
# suicides_n             1200
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
# gdp_for_year              0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
df.loc[df['suicides_n'].isnull()].head(10)
# Out:
#                    country   yea   sex         age  suicides_n  population  \
# 27820  Antigua and Barbuda  2020  male  5-14 years         NaN       92664
# 27821            Argentina  2020  male  5-14 years         NaN    45376763
# 27822              Armenia  2020  male  5-14 years         NaN     2805608
# 27825              Belarus  2020  male  5-14 years         NaN     9379952
# 27826              Belgium  2020  male  5-14 years         NaN    11538604
# 27827               Brazil  2020  male  5-14 years         NaN   213196304
# 27828    Brunei Darussalam  2020  male  5-14 years         NaN      441725
# 27829             Bulgaria  2020  male  5-14 years         NaN     6934015
# 27830               Canada  2020  male  5-14 years         NaN    38037204
# 27831                Chile  2020  male  5-14 years         NaN    19300315
#
#        suicides/100k pop             country-year  HDI for year gdp_for_year  \
# ...

# %%
null_Values=df[df["suicides_n"].isnull()]

# %%
df=df.dropna()

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.title("Heat Map of Null Values in 'suicides_no' Column")
plt.show()

# %%
df.isnull().sum()
# Out:
# country               0
# yea                   0
# sex                   0
# age                   0
# suicides_n            0
# population            0
# suicides/100k pop     0
# country-year          0
# HDI for year          0
# gdp_for_year          0
# gdp_per_capita ($)    0
# generation            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
dd = df.drop(["country","age","sex","country-year","generation","gdp_for_year"],axis=1)

# %%
Df = dd.groupby("yea").mean()["suicides_n"]

# %%
plt.figure(figsize=(11,7))
plt.plot(Df.index, Df.values)
plt.xlabel("Year")
plt.ylabel("Suicide Rate")
plt.title("Change in Suicide Rates from 1985 to 2021",fontdict={"fontweight":"bold","fontsize":12})
plt.show()
